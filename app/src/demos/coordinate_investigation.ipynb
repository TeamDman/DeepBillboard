# %%
import input_reader
import common
import old.utils
import cv2
import common
import input_reader
import numpy as np

# %%
a=4

# %%
images, \
image_size, \
start_points, \
occl_sizes = input_reader.get_input_images("../../resources/digital_Dave_curve1", "jpg")

# %%
print(image_size)
print(start_points[0])
print(occl_sizes[0])
# Out:
# ImageSize(width=256, height=455)
# [31, 27]
# [28, 14]

# %%
common.display_image(images[0][0])

# %%
for image, start, occl in zip(images, start_points, occl_sizes):
    image = image[0]
    image = cv2.resize(image, (0,0), fx=1, fy=1)

    start = np.asarray(start)
    occl = np.asarray(occl)
    print(image.shape, start, occl, start+occl)

    cv2.circle(image, tuple(start), 5, (0,255,0), -1)
    cv2.circle(image, tuple(start + occl), 5, (255,0,0), -1)

    scale = 3
    image = cv2.resize(image, (0,0), fx=scale, fy=scale)
    common.display_image(image)
# Out:
# (100, 100, 3) [31 27] [28 14] [59 41]
# (100, 100, 3) [32 29] [26 12] [58 41]
# (100, 100, 3) [31 30] [26 14] [57 44]
# (100, 100, 3) [32 32] [26 14] [58 46]
# (100, 100, 3) [32 33] [26 12] [58 45]
# (100, 100, 3) [32 34] [26 14] [58 48]
# (100, 100, 3) [32 37] [26 12] [58 49]
# (100, 100, 3) [32 38] [26 12] [58 50]
# (100, 100, 3) [32 39] [26 14] [58 53]
# (100, 100, 3) [32 40] [28 14] [60 54]
# (100, 100, 3) [33 42] [28 14] [61 56]
# (100, 100, 3) [32 43] [28 14] [60 57]
# (100, 100, 3) [32 45] [28 14] [60 59]
# (100, 100, 3) [31 47] [28 14] [59 61]
# (100, 100, 3) [31 48] [28 14] [59 62]
# (100, 100, 3) [31 49] [30 14] [61 63]
# (100, 100, 3) [30 52] [30 14] [60 66]
# (100, 100, 3) [30 53] [30 14] [60 67]
# (100, 100, 3) [30 54] [30 16] [60 70]
# (100, 100, 3) [29 57] [32 16] [61 73]
# (100, 100, 3) [29 58] [32 16] [61 74]
# (100, 100, 3) [28 60] [32 16] [60 76]
# (100, 100, 3) [28 61] [34 18] [62 79]
# (100, 100, 3) [28 62] [34 18] [62 80]
# (100, 100, 3) [27 65] [32 18] [59 83]
# ...
